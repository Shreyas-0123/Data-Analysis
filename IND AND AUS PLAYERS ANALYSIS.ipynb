# %%
import pandas as pd
from pandas import DataFrame as df
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
pd.options.mode.chained_assignment = None
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
data = pd.read_csv(r"C:\Users\SHREYAS\Downloads\cricket.csv")

# %%
data
# Out:
#       player_id      player_name runs_scored wickets runs_conceded catches  \
# 0             1      Pat Cummins         DNB       3            28       0
# 1             2      Steve Smith         DNB       -             -       0
# 2            10      Mitch Marsh          8*       1            19       1
# 3            13     David Warner          20       -             -       0
# 4             1      Pat Cummins         11*       1            73       0
# ...         ...              ...         ...     ...           ...     ...
# 2570         22  Ravindra Jadeja         DNB       3            35       0
# 2571         22  Ravindra Jadeja         DNB       2            41       0
# 2572         22  Ravindra Jadeja          23       0            44       1
# 2573         22  Ravindra Jadeja          57       0            36       0
# 2574         22  Ravindra Jadeja         DNB       4            32       0
#
#      stumpings   match_date                opposition  match_id
# ...

# %%
data["player_name"].unique()
# Out:
# array(['Pat Cummins', 'Steve Smith', 'Mitch Marsh', 'David Warner',
#        'Glenn Maxwell', 'Mitchell Starc.', 'Josh Hazlewood',
#        'Rohit Sharma', 'Virat Kohli', 'Mohammed Shami',
#        'Ravichandran Ashwin', 'Marcus Stoinis', 'Travis Head',
#        'Adam Zampa', 'Hardik Pandya', 'Jasprit Bumrah', 'Kuldeep Yadav',
#        'Alex Carey', 'Ravindra Jadeja', 'KL Rahul', 'Marnus Labuschagne',
#        'Shreyas Iyer', 'Shardul Thakur', 'Cameron Green', 'Josh Inglis',
#        'Sean Abbott', 'Shubman Gill', 'Ishan Kishan', 'Suryakumar Yadav',
#        'Mohammed Siraj'], dtype=object)

# %%
data["match_date"] = data["match_date"].astype("datetime64")

# %%
data["year"] = data["match_date"].dt.year

# %% [markdown]
# # 1 . Pat Cummins

# %%
p_c = data[data["player_name"]== "Pat Cummins"]

# %%
p_c["wickets"] = p_c["wickets"].astype("int64")
p_c["runs_conceded"] = p_c["runs_conceded"].astype("int64")

# %% [markdown]
# # TOTAL WICKETS TAKEN

# %%
p_c["wickets"].sum()
# Out:
# 126

# %%
sns.barplot(x = "year",y  = "wickets",data = p_c)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Per Match

# %%
p_c["wickets"].mean()
# Out:
# 1.6363636363636365

# %% [markdown]
# # Total Runs Conceded

# %%
p_c["runs_conceded"].sum()
# Out:
# 3527

# %%
sns.barplot(x ="year", y ="runs_conceded", data = p_c)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded Per Match

# %%
p_c["runs_conceded"].mean()
# Out:
# 45.8051948051948

# %% [markdown]
# # Best Performance

# %%
p_c.groupby(["wickets"]).max()
# Out:
#          player_id  player_name runs_scored  runs_conceded catches stumpings  \
# wickets
# 0                1  Pat Cummins         DNB             67       2         0
# 1                1  Pat Cummins        TDNB             74       1         0
# 2                1  Pat Cummins         DNB             67       2         0
# 3                1  Pat Cummins         DNB             67       2         0
# 4                1  Pat Cummins         DNB             56       1         0
# 5                1  Pat Cummins         DNB             70       1         0
#
#         match_date                 opposition  match_id  year
# wickets
# 0       2022-06-14      v Sri Lanka Pallekele        70  2022
# 1       2023-09-27  v South Africa Manchester        77  2023
# 2       2022-11-22   v West Indies Nottingham        75  2022
# 3       2022-11-17      v South Africa Sydney        74  2022
# 4       2022-06-16      v Sri Lanka Pallekele        71  2022
# ...

# %% [markdown]
# # WICKETS VS RUNS CONCEDED

# %%
sns.barplot(x = "wickets", y ="runs_conceded",data = p_c)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Catches Taken

# %%
p_c["catches"] = p_c["catches"].astype("int64")

# %%
p_c["catches"].sum()
# Out:
# 20

# %% [markdown]
# ## 2. Sean Abbott

# %% [markdown]
# # TOTAL WICKETS TAKEN

# %%
r_s_a = data[(data["player_name"] == "Sean Abbott") & (data["runs_scored"]!= "DNB") & (data["runs_scored"]!= "TDNB")]

# %%
r_s_a["wickets"] = r_s_a.wickets.astype("int64")

# %%
r_s_a.wickets.sum()
# Out:
# 13

# %%
sns.barplot(x = 'year', y ='wickets',data = r_s_a)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Taken

# %%
r_s_a["wickets"].mean()
# Out:
# 0.9285714285714286

# %% [markdown]
# # TOTAL RUNS Conceded

# %%
r_s_a["runs_conceded"] = r_s_a["runs_conceded"].astype("int64")

# %%
r_s_a["runs_conceded"].sum()
# Out:
# 638

# %%
sns.barplot(x = "year", y = "runs_conceded", data = r_s_a)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded

# %%
r_s_a["runs_conceded"].mean()
# Out:
# 45.57142857142857

# %% [markdown]
# # Wickets Vs Runs Conceded

# %%
sns.barplot(x = "wickets", y = 'runs_conceded',data = r_s_a)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Total Runs Scored

# %%
r_s_a.runs_scored = r_s_a.runs_scored.str.replace("*","")

# %%
r_s_a.runs_scored = r_s_a.runs_scored.astype("int64")

# %%
r_s_a.runs_scored.sum()
# Out:
# 228

# %%
sns.barplot(x = "year",y = "runs_scored",data = r_s_a)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# # Average Runs Scored Per Match

# %%
r_s_a.runs_scored.mean()
# Out:
# 16.285714285714285

# %% [markdown]
# # Catches Taken

# %%
r_s_a["catches"] = r_s_a["catches"].astype("int64")

# %%
r_s_a["catches"].sum()
# Out:
# 6

# %% [markdown]
# # Best Performance

# %%
r_s_a.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id  player_name  runs_conceded  catches stumpings  \
# runs_scored wickets
# 0           0                5  Sean Abbott             31        0         0
# 2           0                5  Sean Abbott             31        1         0
#             1                5  Sean Abbott             56        0         0
# 3           1                5  Sean Abbott             25        0         0
# 4           1                5  Sean Abbott             84        0         0
# 7           2                5  Sean Abbott             50        1         0
# 9           1                5  Sean Abbott             40        0         0
# 14          1                5  Sean Abbott             36        1         0
# 23          2                5  Sean Abbott             54        1         0
# 26          1                5  Sean Abbott             50        1         0
# 28          0                5  Sean Abbott             74        1         0
# ...

# %% [markdown]
# # 3. Adam Zampa

# %%
a_z = data[data["player_name"]=="Adam Zampa"]

# %%
a_z["wickets"] = a_z["wickets"].astype("int64")
a_z["runs_conceded"] = a_z["runs_conceded"].astype("int64")

# %% [markdown]
# # TOTAL WICKETS TAKEN

# %%
a_z.wickets.sum()
# Out:
# 142

# %%
sns.barplot(x = "year",y = "wickets", data = a_z)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets per match

# %%
a_z["wickets"].mean()
# Out:
# 1.6705882352941177

# %% [markdown]
# # Total Runs Conceded

# %%
a_z.runs_conceded.sum()
# Out:
# 4126

# %%
sns.barplot(x = "year", y = "runs_conceded",data = a_z)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded per match

# %%
r_s_a["runs_conceded"].mean()
# Out:
# 45.57142857142857

# %% [markdown]
# # Wickets vs Runs Conceded

# %%
sns.barplot(x = "wickets", y = "runs_conceded",data = a_z)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Catches Taken

# %%
a_z["catches"] = a_z["catches"].astype("int64")

# %%
a_z["catches"].sum()
# Out:
# 16

# %% [markdown]
# # Best Performance

# %%
a_z.groupby(["wickets"]).max()
# Out:
#          player_id player_name runs_scored  runs_conceded  catches stumpings  \
# wickets
# 0               14  Adam Zampa         DNB            113        1         0
# 1               14  Adam Zampa         DNB             68        1         0
# 2               14  Adam Zampa         DNB             71        1         0
# 3               14  Adam Zampa         DNB             70        2         0
# 4               14  Adam Zampa         DNB             55        0         0
# 5               14  Adam Zampa          16             35        1         0
#
#         match_date                   opposition  match_id  year
# wickets
# 0       2023-09-15        v Zimbabwe Townsville       182  2023
# 1       2023-09-24     v West Indies Nottingham       188  2023
# 2       2023-09-22     v West Indies Bridgetown       189  2023
# 3       2023-09-17        v Zimbabwe Townsville       187  2023
# 4       2023-09-09  v South Africa Bloemfontein       180  2023
# ...

# %% [markdown]
# # 4. Josh Hazlewood

# %%
j_z = data[data["player_name"] == "Josh Hazlewood"]

# %%
j_z_a = data[(data["player_name"] == "Josh Hazlewood") & (data["wickets"]!= "-")]

# %%
j_z_a.wickets = j_z_a.wickets.astype("int64")

# %% [markdown]
# # Total Wickets Taken

# %%
j_z_a.wickets.sum()
# Out:
# 116

# %%
sns.barplot(x = 'year',y = 'wickets',data=j_z_a)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Taken Per Match

# %%
j_z_a.wickets.mean()
# Out:
# 1.5890410958904109

# %% [markdown]
# # Total Runs Conceded

# %%
j_z_a.runs_conceded = j_z_a.runs_conceded.astype("int64")

# %%
j_z_a.runs_conceded.sum()
# Out:
# 3064

# %%
sns.barplot(x = "year",y = "runs_conceded",data = j_z_a)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded

# %%
j_z_a.runs_conceded.mean()
# Out:
# 41.97260273972603

# %% [markdown]
# # Wickets vs Runs Conceded

# %%
sns.barplot(x = "wickets", y = "runs_conceded",data = j_z_a)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Catches Taken

# %%
j_z["catches"] = j_z["catches"].astype("int64")

# %%
j_z["catches"].sum()
# Out:
# 23

# %% [markdown]
# # Best Performance

# %%
j_z.groupby(["wickets"]).max()
# Out:
#          player_id     player_name runs_scored runs_conceded  catches  \
# wickets
# -                8  Josh Hazlewood        TDNB             -        0
# 0                8  Josh Hazlewood        TDNB            74        2
# 1                8  Josh Hazlewood         DNB            74        1
# 2                8  Josh Hazlewood         DNB            79        1
# 3                8  Josh Hazlewood         DNB            61        2
# 4                8  Josh Hazlewood         DNB            35        0
# 5                8  Josh Hazlewood          0*            50        1
# 6                8  Josh Hazlewood         DNB            52        0
#
#         stumpings match_date                 opposition  match_id  year
# wickets
# -               0 2016-06-19  v South Africa Bridgetown       137  2016
# 0               0 2023-09-12      v Zimbabwe Townsville       185  2023
# 1               0 2023-09-24      v Zimbabwe Townsville       187  2023
# ...

# %% [markdown]
# # 5. Mitchell Starc

# %%
m_s = data[data["player_name"]=="Mitchell Starc."]

# %%
m_s.wickets  = m_s.wickets.astype('int64')

# %% [markdown]
# # Total Wickets Taken

# %%
m_s.wickets.sum()
# Out:
# 220

# %%
sns.barplot(x = "year",y = "wickets",data = m_s)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# ## Average Wickets Taken

# %%
m_s.wickets.mean()
# Out:
# 1.981981981981982

# %% [markdown]
# # Total Runs conceded

# %%
m_s.runs_conceded  = m_s.runs_conceded.astype("int64")

# %%
m_s.runs_conceded.sum()
# Out:
# 4892

# %%
sns.barplot(x = 'year', y = 'runs_conceded',data = m_s)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded

# %%
m_s.runs_conceded.mean()
# Out:
# 44.072072072072075

# %% [markdown]
# # Wickets vs Runs conceded

# %%
sns.barplot(x = m_s["wickets"],y = m_s["runs_conceded"],data = m_s)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Catches taken

# %%
m_s.catches = m_s.catches.astype("int64")

# %%
m_s.catches.sum()
# Out:
# 38

# %% [markdown]
# # Best Performance

# %%
m_s.groupby(["wickets"]).max()
# Out:
#          player_id      player_name runs_scored  runs_conceded  catches  \
# wickets
# 0               15  Mitchell Starc.        TDNB             82        2
# 1               15  Mitchell Starc.        TDNB             79        3
# 2               15  Mitchell Starc.         DNB             71        2
# 3               15  Mitchell Starc.         DNB             74        1
# 4               15  Mitchell Starc.         DNB             59        1
# 5               15  Mitchell Starc.         DNB             53        1
# 6               15  Mitchell Starc.         DNB             43        1
#
#         stumpings match_date                opposition  match_id  year
# wickets
# 0               0 2023-03-22  v West Indies Bridgetown       243  2023
# 1               0 2023-09-27     v Zimbabwe Townsville       228  2023
# 2               0 2022-09-08         v Zimbabwe Harare       242  2022
# 3               0 2023-03-17     v Zimbabwe Townsville       189  2023
# ...

# %% [markdown]
# # 6. Mitch Marsh

# %%
m_m = data[(data["player_name"] == "Mitch Marsh") & (data["runs_scored"] != "DNB") & (data["runs_scored"] != "TDNB")]

# %%
m_m["runs_scored"] = m_m["runs_scored"].str.replace("*","")

# %%
m_m_w = data[(data["player_name"] == "Mitch Marsh") & (data["wickets"]!= "-") & (data["runs_conceded"] != "-")]

# %%
m_m_w
# Out:
#       player_id  player_name runs_scored wickets runs_conceded catches  \
# 2            10  Mitch Marsh          8*       1            19       1
# 46           10  Mitch Marsh           0       0            11       0
# 57           10  Mitch Marsh          11       0            26       0
# 63           10  Mitch Marsh         40*       1            35       2
# 69           10  Mitch Marsh          64       1            51       1
# ...         ...          ...         ...     ...           ...     ...
# 1150         10  Mitch Marsh           8       0            19       0
# 1233         10  Mitch Marsh          10       0            50       2
# 1258         10  Mitch Marsh           5       0            13       0
# 1263         10  Mitch Marsh           4       0            12       0
# 1265         10  Mitch Marsh          15       0            13       0
#
#      stumpings match_date                opposition  match_id  year
# ...

# %% [markdown]
# # Total Runs Scored

# %%
m_m.runs_scored = m_m.runs_scored.astype("int64")

# %%
m_m.runs_scored.sum()
# Out:
# 2231

# %%
sns.barplot(x = "year", y = "runs_scored",data = m_m)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# # Average Runs Scored

# %%
m_m.runs_scored.mean()
# Out:
# 29.746666666666666

# %% [markdown]
# # Total Wicekts Taken

# %%
m_m_w.wickets = m_m_w.wickets.astype("int64")

# %%
m_m_w.wickets.sum()
# Out:
# 54

# %%
sns.barplot(x = "year", y= "wickets",data = m_m_w)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Taken

# %%
m_m_w.wickets.mean()
# Out:
# 0.84375

# %% [markdown]
# # Total Runs Conceded

# %%
m_m_w.runs_conceded = m_m_w.runs_conceded.astype("int64")

# %%
m_m_w.runs_conceded.sum()
# Out:
# 1913

# %%
sns.barplot(x = "year",y = "runs_conceded",data = m_m_w)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded

# %%
m_m_w['runs_conceded'].mean()
# Out:
# 29.890625

# %% [markdown]
# # Wickets vs Runs Conceded

# %%
sns.barplot(x = 'wickets',y = 'runs_conceded',data = m_m_w)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Catches Taken

# %%
m_m.catches = m_m.catches.astype("int64")

# %%
m_m.catches.sum()
# Out:
# 35

# %% [markdown]
# # Best Performance

# %%
m_m.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id  player_name runs_conceded  catches stumpings  \
# runs_scored wickets
# 0           -               10  Mitch Marsh             -        0         0
#             0               10  Mitch Marsh            32        0         0
#             2               10  Mitch Marsh            35        0         0
# 1           1               10  Mitch Marsh            49        0         0
#             2               10  Mitch Marsh            38        0         0
# ...                        ...          ...           ...      ...       ...
# 81          -               10  Mitch Marsh             -        0         0
# 86          2               10  Mitch Marsh            23        1         0
# 89          1               10  Mitch Marsh            15        1         0
# 96          -               10  Mitch Marsh             -        0         0
# 102         1               10  Mitch Marsh            77        0         0
#
# ...

# %% [markdown]
# # 7. Glenn Maxwell

# %%
g_m = data[data["player_name"] == "Glenn Maxwell"]

# %%
g_m["runs_scored"] = g_m["runs_scored"].str.replace("*","")

# %% [markdown]
# # Total Runs Scored

# %%
g_m_w = g_m[(g_m["runs_scored"]!="DNB") & (g_m["runs_scored"]!= "TDNB")]

# %%
g_m_w["runs_scored"] = g_m_w["runs_scored"].astype("int64")

# %%
g_m_w.runs_scored.sum()
# Out:
# 3495

# %%
sns.barplot(x = "year",y = "runs_scored",data = g_m_w)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# # Average Runs Scored

# %%
g_m_w.runs_scored.mean()
# Out:
# 29.61864406779661

# %% [markdown]
# # Total Wickets Taken

# %%
g_m_r = g_m[g_m["wickets"]!= "-"]

# %%
g_m_r.wickets  = g_m_r.wickets.astype("int64")

# %%
g_m_r.wickets.sum()
# Out:
# 64

# %%
sns.barplot(x = "year",y = "wickets",data = g_m_r)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Taken

# %%
g_m_r.wickets.mean()
# Out:
# 0.6274509803921569

# %% [markdown]
# # Total Runs Conceded

# %%
g_m_c = g_m[g_m["runs_conceded"]!= "-"]

# %%
g_m_c.runs_conceded = g_m_c.runs_conceded.astype("int64")

# %%
g_m_c.runs_conceded.sum()
# Out:
# 3054

# %%
sns.barplot(x = 'year', y = 'runs_conceded',data = g_m_c)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded

# %%
g_m_c.runs_conceded.mean()
# Out:
# 29.941176470588236

# %% [markdown]
# # Wickets vs Runs Conceded

# %%
sns.barplot(x = 'year',y = 'runs_conceded',data = g_m_c)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Catches Taken

# %%
g_m.catches = g_m.catches.astype("int64")

# %%
g_m.catches.sum()
# Out:
# 81

# %% [markdown]
# # Best Performance

# %%
g_m_w.groupby(["runs_scored"]).max()
# Out:
#              player_id    player_name wickets runs_conceded catches stumpings  \
# runs_scored
# 0                   11  Glenn Maxwell       4            63       4         0
# 1                   11  Glenn Maxwell       1             7       2         0
# 2                   11  Glenn Maxwell       4            52       1         0
# 3                   11  Glenn Maxwell       2             8       0         0
# 4                   11  Glenn Maxwell       1            45       1         0
# ...                ...            ...     ...           ...     ...       ...
# 95                  11  Glenn Maxwell       4            46       2         0
# 96                  11  Glenn Maxwell       0            46       2         0
# 98                  11  Glenn Maxwell       0            41       1         0
# 102                 11  Glenn Maxwell       0            35       0         0
# 108                 11  Glenn Maxwell       0            23       1         0
#
# ...

# %% [markdown]
# # 8 .Steve Smith

# %%
s_s = data[(data["player_name"]=="Steve Smith") &(data["runs_scored"]!="TDNB")& (data["runs_scored"]!="DNB")]

# %%
s_s.runs_scored = s_s.runs_scored.str.replace("*","")
s_s.runs_scored = s_s.runs_scored.astype("int64")

# %% [markdown]
# # Total Runs Scored

# %%
s_s.runs_scored.sum()
# Out:
# 5054

# %%
sns.barplot(x = "year", y = "runs_scored",data = s_s)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# # Average Runs Scored = 39

# %%
s_s.runs_scored.mean()
# Out:
# 39.17829457364341

# %% [markdown]
# # Total Catches Taken = 71

# %%
s_s.catches = s_s.catches.astype('int64')

# %%
s_s.catches.sum()
# Out:
# 71

# %% [markdown]
# # Best Performance At Sydney Vs New Zealand

# %%
s_s.groupby(["runs_scored"]).max()
# Out:
#              player_id  player_name wickets runs_conceded  catches stumpings  \
# runs_scored
# 0                    2  Steve Smith       1             5        1         0
# 1                    2  Steve Smith       3            41        2         0
# 2                    2  Steve Smith       -             -        2         0
# 3                    2  Steve Smith       -             -        0         0
# 4                    2  Steve Smith       -             -        1         0
# ...                ...          ...     ...           ...      ...       ...
# 105                  2  Steve Smith       -             -        3         0
# 108                  2  Steve Smith       -             -        0         0
# 131                  2  Steve Smith       -             -        0         0
# 149                  2  Steve Smith       -             -        0         0
# 164                  2  Steve Smith       -             -        2         0
#
# ...

# %% [markdown]
# # 9.David Warner

# %%
d_w = data[(data["player_name"] == "David Warner") & (data["runs_scored"]!= "DNB") & (data["runs_scored"]!="TDNB")]

# %%
d_w.runs_scored = d_w.runs_scored.str.replace("*","")

# %%
d_w.runs_scored = d_w.runs_scored.astype("int64")

# %% [markdown]
# # Total Runs Scored

# %%
d_w.runs_scored.sum()
# Out:
# 6397

# %%
sns.barplot(x = "year", y = "runs_scored",data = d_w)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# # Average Runs Scored = 43

# %%
d_w.runs_scored.mean()
# Out:
# 43.222972972972975

# %% [markdown]
# # Catches Taken = 62

# %%
d_w.catches = d_w.catches.astype("int64")

# %%
d_w.catches.sum()
# Out:
# 62

# %% [markdown]
# # Best Performance

# %%
d_w.groupby(["runs_scored"]).max()
# Out:
#              player_id   player_name wickets runs_conceded  catches stumpings  \
# runs_scored
# 0                   13  David Warner       -             -        2         0
# 1                   13  David Warner       -             -        1         0
# 2                   13  David Warner       0             8        0         0
# 3                   13  David Warner       -             -        0         0
# 4                   13  David Warner       -             -        2         0
# ...                ...           ...     ...           ...      ...       ...
# 163                 13  David Warner       -             -        0         0
# 166                 13  David Warner       -             -        2         0
# 173                 13  David Warner       -             -        0         0
# 178                 13  David Warner       -             -        1         0
# 179                 13  David Warner       -             -        0         0
#
# ...

# %% [markdown]
# # 10.Rohit Sharma

# %%
r_s = data[(data["player_name"] == "Rohit Sharma") & (data["runs_scored"]!= "DNB") & (data["runs_scored"]!= "TDNB")& (data["catches"]!= "-")]
r_s["runs_scored"] = r_s["runs_scored"].str.replace("*","")

# %%
r_s.runs_scored = r_s.runs_scored.astype("int64")
r_s.catches = r_s.catches.astype("int64")

# %% [markdown]
# # Total Runs Scored

# %%
r_s.runs_scored.sum()
# Out:
# 10101

# %%
sns.barplot(x = "year",  y = "runs_scored",data = r_s)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# # Average Runs Scored

# %%
r_s.runs_scored.mean()
# Out:
# 41.912863070539416

# %% [markdown]
# # Total Catches Taken

# %%
r_s.catches.sum()
# Out:
# 87

# %% [markdown]
# ## Best Performance

# %%
r_s.groupby(["runs_scored"]).max()
# Out:
#              player_id   player_name wickets runs_conceded  catches stumpings  \
# runs_scored
# 0                   16  Rohit Sharma       2             5        1         0
# 1                   16  Rohit Sharma       0             6        1         0
# 2                   16  Rohit Sharma       -             -        0         0
# 3                   16  Rohit Sharma       0             7        1         0
# 4                   16  Rohit Sharma       0             6        2         0
# ...                ...           ...     ...           ...      ...       ...
# 162                 16  Rohit Sharma       -             -        3         0
# 171                 16  Rohit Sharma       0            11        0         0
# 208                 16  Rohit Sharma       -             -        1         0
# 209                 16  Rohit Sharma       -             -        0         0
# 264                 16  Rohit Sharma       -             -        0         0
#
# ...

# %% [markdown]
# # 11. Virat Kohli

# %%
v_k = data[(data["player_name"]== "Virat Kohli") & (data["runs_scored"]!= "DNB")&(data["runs_scored"]!= "TDNB")& (data["catches"]!= "-")]

# %%
v_k.catches = v_k.catches.astype("int64")

# %% [markdown]
# # Total Runs Scored

# %%
v_k.runs_scored = v_k.runs_scored.str.replace("*","")

# %%
v_k.runs_scored = v_k.runs_scored.astype("int64")

# %%
v_k.runs_scored.sum()
# Out:
# 13044

# %%
sns.barplot(x = "year",y = "runs_scored",data  = v_k)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# # Average Runs Scored Per Match

# %%
v_k.runs_scored.mean()
# Out:
# 49.037593984962406

# %% [markdown]
# # Catches Taken

# %%
v_k.catches.sum()
# Out:
# 137

# %% [markdown]
# # Best Performance

# %%
v_k.groupby(["runs_scored"]).max()
# Out:
#              player_id  player_name wickets runs_conceded  catches stumpings  \
# runs_scored
# 0                   19  Virat Kohli       0             7        2         0
# 1                   19  Virat Kohli       0             7        2         0
# 2                   19  Virat Kohli       0             9        1         0
# 3                   19  Virat Kohli       -             -        1         0
# 4                   19  Virat Kohli       -             -        1         0
# ...                ...          ...     ...           ...      ...       ...
# 154                 19  Virat Kohli       -             -        1         0
# 157                 19  Virat Kohli       -             -        1         0
# 160                 19  Virat Kohli       -             -        2         0
# 166                 19  Virat Kohli       -             -        0         0
# 183                 19  Virat Kohli       -             -        2         0
#
# ...

# %% [markdown]
# # 12.Mohammad Shami

# %%
mo_s = data[(data["player_name"] == "Mohammed Shami") & (data["wickets"] != "-") & (data["runs_conceded"] != "-")]

# %%
mo_s.wickets = mo_s.wickets.astype("int64")

# %%
mo_s.runs_conceded  = mo_s.runs_conceded.astype("int64")

# %% [markdown]
# # Total Wickets Taken

# %%
mo_s.wickets.sum()
# Out:
# 171

# %%
sns.barplot(x = "year", y = "wickets",data = mo_s)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Taken

# %%
mo_s.wickets.mean()
# Out:
# 1.8387096774193548

# %% [markdown]
# # Total Runs Conceded

# %%
mo_s.runs_conceded.sum()
# Out:
# 4361

# %%
sns.barplot(x = "year",y = 'runs_conceded',data = mo_s)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded

# %%
mo_s.runs_conceded.mean()
# Out:
# 46.89247311827957

# %% [markdown]
# # Wickets vs Runs Conceded

# %%
sns.barplot(x = 'wickets', y = 'runs_conceded',data = mo_s)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Catches Taken

# %%
mo_s.catches = mo_s.catches.astype("int64")

# %%
mo_s.catches.sum()
# Out:
# 29

# %% [markdown]
# # Best Performance

# %%
mo_s.groupby(["wickets"]).max()
# Out:
#          player_id     player_name runs_scored  runs_conceded  catches  \
# wickets
# 0               27  Mohammed Shami        TDNB             68        1
# 1               27  Mohammed Shami         DNB             73        1
# 2               27  Mohammed Shami         DNB             84        2
# 3               27  Mohammed Shami        TDNB             81        2
# 4               27  Mohammed Shami         DNB             66        1
# 5               27  Mohammed Shami         DNB             69        1
#
#         stumpings match_date                opposition  match_id  year
# wickets
# 0               0 2023-03-22  v West Indies Providence       540  2023
# 1               0 2023-09-24         v Zimbabwe Harare       542  2023
# 2               0 2023-09-15         v Zimbabwe Harare       536  2023
# 3               0 2023-03-17       v Zimbabwe Auckland       532  2023
# 4               0 2020-01-19  v West Indies Manchester       535  2020
# ...

# %% [markdown]
# # 13 . Ravichandran Ashwin

# %%
rc_a = data[(data["player_name"] == "Ravichandran Ashwin") & (data["wickets"] != "-") & (data["runs_conceded"] != "-") ]

# %%
rc_a.wickets = rc_a.wickets.astype("int64")

# %%
rc_a.runs_conceded = rc_a.runs_conceded.astype("int64")

# %% [markdown]
# # Total Wickets

# %%
rc_a.wickets.sum()
# Out:
# 155

# %%
sns.barplot(x = "year", y ="wickets",data = rc_a)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Taken

# %%
rc_a.wickets.mean()
# Out:
# 1.3716814159292035

# %% [markdown]
# ## Total Runs Conceded

# %%
rc_a.runs_conceded.sum()
# Out:
# 5146

# %%
sns.barplot(x = "year", y = "runs_conceded",data = rc_a)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# # Average Runs Conceded

# %%
rc_a.runs_conceded.mean()
# Out:
# 45.53982300884956

# %% [markdown]
# # Wickets vs Runs conceded

# %%
sns.barplot(x = "wickets", y = "runs_conceded", data = rc_a)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# # Catches Taken

# %%
rc_a.catches = rc_a.catches.astype("int64")

# %%
rc_a.catches.sum()
# Out:
# 31

# %% [markdown]
# ## Best Performance

# %%
rc_a.groupby(["wickets"]).max()
# Out:
#          player_id          player_name runs_scored  runs_conceded  catches  \
# wickets
# 0               28  Ravichandran Ashwin        TDNB             70        2
# 1               28  Ravichandran Ashwin         DNB             75        1
# 2               28  Ravichandran Ashwin         DNB             68        3
# 3               28  Ravichandran Ashwin         DNB             65        1
# 4               28  Ravichandran Ashwin         DNB             25        0
#
#         stumpings match_date                   opposition  match_id  year
# wickets
# 0               0 2022-01-21  v West Indies Port of Spain       546  2022
# 1               0 2023-09-22          v Zimbabwe Auckland       545  2023
# 2               0 2016-01-12  v West Indies Visakhapatnam       538  2016
# 3               0 2023-09-24    v West Indies North Sound       531  2023
# 4               0 2015-02-28               v U.A.E. Perth       363  2015

# %% [markdown]
# ## 14. Marcus Stoinis

# %%
ma_s = data[(data["player_name"] == "Marcus Stoinis") & (data["wickets"]!= "-") & (data["runs_conceded"]!= "-") & (data["runs_scored"]!="DNB") & (data["runs_scored"]!= "TDNB")]

# %%
ma_s.runs_scored = ma_s.runs_scored.str.replace("*", "")

# %%
ma_s.runs_scored = ma_s.runs_scored.astype("int64")

# %% [markdown]
# ## Total Runs Scored

# %%
ma_s.runs_scored.sum()
# Out:
# 1237

# %%
sns.barplot(x = 'year', y = 'runs_scored',data = ma_s)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
ma_s.runs_scored.mean()
# Out:
# 23.78846153846154

# %% [markdown]
# ## Total Wickets

# %%
ma_s.wickets = ma_s.wickets.astype("int64")

# %%
ma_s.wickets.sum()
# Out:
# 41

# %%
sns.barplot(x = "year", y = "runs_scored", data = ma_s)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Wickets Taken

# %%
ma_s.wickets.mean()
# Out:
# 0.7884615384615384

# %% [markdown]
# ## Total Catches Taken

# %%
ma_s.catches = ma_s.catches.astype("int64")

# %%
ma_s.catches.sum()
# Out:
# 12

# %% [markdown]
# ## Best Performance

# %%
ma_s.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id     player_name runs_conceded  catches  \
# runs_scored wickets
# 0           0               12  Marcus Stoinis            25        0
#             1               12  Marcus Stoinis            14        0
#             2               12  Marcus Stoinis            62        1
# 1           0               12  Marcus Stoinis            41        0
# 2           2               12  Marcus Stoinis            20        0
#             3               12  Marcus Stoinis            35        0
# 3           1               12  Marcus Stoinis             6        0
#             2               12  Marcus Stoinis            54        0
# 4           0               12  Marcus Stoinis            34        0
# 5           0               12  Marcus Stoinis            25        0
#             2               12  Marcus Stoinis            27        0
# 8           1               12  Marcus Stoinis            29        1
# ...

# %% [markdown]
# ## 15. Travis Head

# %%
t_h = data[(data["player_name"] == "Travis Head") & (data["runs_scored"]!="DNB")& (data["runs_scored"]!="TDNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
t_h.runs_scored = t_h.runs_scored.str.replace("*","")

# %%
t_h.runs_scored = t_h.runs_scored.astype("int64")

# %%
t_h.runs_scored.sum()
# Out:
# 2064

# %%
sns.barplot(x= "year",y = "runs_scored",data = t_h)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
t_h.runs_scored.mean()
# Out:
# 37.527272727272724

# %% [markdown]
# ## Total Wickets Taken

# %%
t_h_w  = t_h[(t_h["wickets"]!= "-") & (t_h["runs_conceded"]!= "-")]

# %%
t_h_w.wickets = t_h_w.wickets.astype("int64")

# %%
t_h_w.wickets.sum()
# Out:
# 15

# %%
sns.countplot(y = "wickets",data = t_h_w)
# Out:
# <Axes: xlabel='count', ylabel='wickets'>

# %% [markdown]
# # Average Wickets Taken

# %%
t_h_w.wickets.mean()
# Out:
# 0.5

# %% [markdown]
# ## Catches Taken

# %%
t_h_w.catches = t_h_w.catches.astype("int64")

# %%
t_h_w.catches.sum()
# Out:
# 11

# %% [markdown]
# ## Best Performance

# %%
t_h_w.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id  player_name runs_conceded  catches stumpings  \
# runs_scored wickets
# 0           0                9  Travis Head             9        0         0
# 1           0                9  Travis Head            29        0         0
# 5           0                9  Travis Head             6        0         0
#             1                9  Travis Head            21        1         0
# 7           0                9  Travis Head            55        0         0
# 10          0                9  Travis Head            18        2         0
# 13          2                9  Travis Head            22        0         0
# 18          0                9  Travis Head            16        2         0
# 23          2                9  Travis Head            65        1         0
# 29          0                9  Travis Head            38        0         0
# 31          0                9  Travis Head            41        0         0
# ...

# %% [markdown]
# ## 16. Hardik Pandya

# %%
hp = data[(data["player_name"] == "Hardik Pandya") & (data["runs_scored"]!= "DNB") & (data["runs_scored"]!= "TDNB")]

# %%
hp["runs_scored"] = hp["runs_scored"].str.replace("*","")
hp["wickets"] = hp.wickets.str.replace("-","0")

# %%
hp["runs_conceded"] = hp["runs_conceded"].str.replace("-","0")

# %%
hp
# Out:
#       player_id    player_name runs_scored wickets runs_conceded catches  \
# 191          17  Hardik Pandya          83       2            28       0
# 202          17  Hardik Pandya          20       2            56       1
# 213          17  Hardik Pandya          78       1            58       0
# 224          17  Hardik Pandya          41       0            32       1
# 368          17  Hardik Pandya          48       0            68       0
# 534          17  Hardik Pandya          90       0             0       0
# 550          17  Hardik Pandya          28       1            24       0
# 940          17  Hardik Pandya          92       0             0       0
# 1028         17  Hardik Pandya          25       1            29       1
# 1050         17  Hardik Pandya           1       0            18       0
# 1070         17  Hardik Pandya          40       3            44       1
# 1766         17  Hardik Pandya          36       0            45       0
# ...

# %% [markdown]
# ## Total Runs Scored

# %%
hp.runs_scored = hp.runs_scored.astype('int64')

# %%
hp.runs_scored.sum()
# Out:
# 1758

# %%
sns.barplot(x = "year",y  = "runs_scored",data = hp)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
hp.runs_scored.mean()
# Out:
# 29.3

# %% [markdown]
# ## Total Wickets Taken

# %%
hp.wickets = hp.wickets.astype("int64")

# %%
hp.wickets.sum()
# Out:
# 57

# %%
sns.barplot(x = "year",y = "wickets",data= hp)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# ## Average Wickets Taken

# %%
hp.wickets.mean()
# Out:
# 0.95

# %% [markdown]
# ## Total Runs Conceded

# %%
hp.runs_conceded = hp.runs_conceded.astype("int64")

# %%
hp.runs_conceded.sum()
# Out:
# 2182

# %%
sns.barplot(x = "year",y = "runs_conceded",data = hp)
# Out:
# <Axes: xlabel='year', ylabel='runs_conceded'>

# %% [markdown]
# ## Average Runs Conceded

# %%
hp.runs_conceded.mean()
# Out:
# 36.36666666666667

# %% [markdown]
# ## Best Performance

# %%
hp.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id    player_name  runs_conceded catches  \
# runs_scored wickets
# 0           0               17  Hardik Pandya             20       0
#             1               17  Hardik Pandya             24       0
#             2               17  Hardik Pandya             30       1
#             3               17  Hardik Pandya             60       0
# 1           0               17  Hardik Pandya             18       0
# 3           0               17  Hardik Pandya             41       2
# 4           0               17  Hardik Pandya             32       1
# 5           1               17  Hardik Pandya             17       1
# 7           0               17  Hardik Pandya             38       0
#             1               17  Hardik Pandya             50       1
#             2               17  Hardik Pandya             51       1
# 8           0               17  Hardik Pandya             47       0
# ...

# %% [markdown]
# ## 17. Jasprit Bumrah

# %%
jp1 = data[(data["player_name"]=="Jasprit Bumrah") & (data["wickets"]!= "-")]

# %%
jp1
# Out:
#       player_id     player_name runs_scored wickets runs_conceded catches  \
# 193          24  Jasprit Bumrah         DNB       1            20       2
# 204          24  Jasprit Bumrah         10*       0            39       0
# 215          24  Jasprit Bumrah         DNB       2            52       1
# 236          24  Jasprit Bumrah         DNB       2            51       1
# 293          24  Jasprit Bumrah         DNB       2            60       0
# ...         ...             ...         ...     ...           ...     ...
# 2547         24  Jasprit Bumrah         DNB       1            37       0
# 2552         24  Jasprit Bumrah          12       2            52       0
# 2562         24  Jasprit Bumrah         DNB       4            28       0
# 2564         24  Jasprit Bumrah         DNB       1            27       1
# 2566         24  Jasprit Bumrah         DNB       4            22       1
#
#      stumpings match_date                opposition  match_id  year
# ...

# %% [markdown]
# ## Total Wickets Taken

# %%
jp1.wickets = jp1.wickets.astype("int64")

# %%
jp1.wickets.sum()
# Out:
# 129

# %%
sns.barplot(x= 'year', y ="wickets",data=jp1)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# ## Average Wickets Taken

# %%
jp1.wickets.mean()
# Out:
# 1.6753246753246753

# %% [markdown]
# ## Total Runs Conceded

# %%
jp1.runs_conceded = jp1.runs_conceded.astype("int64")

# %%
jp1.runs_conceded.sum()
# Out:
# 3136

# %% [markdown]
# ## Average Runs Conceded

# %%
jp1.runs_conceded.mean()
# Out:
# 40.72727272727273

# %% [markdown]
# ## Wickets VS Runs Conceded

# %%
sns.barplot(x = "wickets",y= "runs_conceded",data=jp1)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# ## Best Performance

# %%
jp1.groupby(["wickets"]).max()
# Out:
#          player_id     player_name runs_scored  runs_conceded catches  \
# wickets
# 0               24  Jasprit Bumrah         DNB             68       1
# 1               24  Jasprit Bumrah         DNB             79       2
# 2               24  Jasprit Bumrah         DNB             81       1
# 3               24  Jasprit Bumrah         DNB             81       1
# 4               24  Jasprit Bumrah         DNB             55       1
# 5               24  Jasprit Bumrah         DNB             27       1
# 6               24  Jasprit Bumrah         DNB             19       0
#
#         stumpings match_date                        opposition  match_id  year
# wickets
# 0               0 2020-02-11           v West Indies Brabourne       544  2020
# 1               0 2023-09-22                 v Zimbabwe Harare       550  2023
# 2               0 2023-09-12  v West Indies Thiruvananthapuram       547  2023
# ...

# %% [markdown]
# ## 18. Kuldeep Yadav

# %%
ky = data[(data["player_name"] == "Kuldeep Yadav")& (data["wickets"] != "-")]

# %% [markdown]
# ## Total Wicekts Taken

# %%
ky.wickets =ky.wickets.astype("int64")

# %%
ky.wickets.sum()
# Out:
# 152

# %%
sns.barplot(x= "year",y = "wickets",data = ky)
# Out:
# <Axes: xlabel='year', ylabel='wickets'>

# %% [markdown]
# ## Average Wickets Taken

# %%
ky.wickets.mean()
# Out:
# 1.7471264367816093

# %% [markdown]
# ## Total Runs Conceded

# %%
ky.runs_conceded = ky.runs_conceded.astype("int64")

# %%
ky.runs_conceded.sum()
# Out:
# 3895

# %% [markdown]
# ## Average Runs Conceded

# %%
ky.runs_conceded.mean()
# Out:
# 44.770114942528735

# %% [markdown]
# ## Wickets vs Runs Conceded

# %%
sns.barplot(x= "wickets",y = "runs_conceded",data= ky)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# ## Best Performance

# %%
ky.groupby(["wickets"]).max()
# Out:
#          player_id    player_name runs_scored  runs_conceded catches  \
# wickets
# 0               26  Kuldeep Yadav         DNB             84       1
# 1               26  Kuldeep Yadav        TDNB             74       1
# 2               26  Kuldeep Yadav         DNB             84       1
# 3               26  Kuldeep Yadav         DNB             68       1
# 4               26  Kuldeep Yadav         DNB             57       1
# 5               26  Kuldeep Yadav         DNB             25       1
# 6               26  Kuldeep Yadav         DNB             25       0
#
#         stumpings match_date                   opposition  match_id  year
# wickets
# 0               0 2023-09-17            v Zimbabwe Harare       475  2023
# 1               0 2023-07-29            v Zimbabwe Harare       548  2023
# 2               0 2023-09-27            v Zimbabwe Harare       552  2023
# 3               0 2023-03-22  v West Indies Visakhapatnam       464  2023
# ...

# %% [markdown]
# ## 18.Alex Carey

# %%
a_c = data[(data["player_name"] == "Alex Carey")&(data["runs_scored"]!= "TDNB")& (data["runs_scored"]!="DNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
a_c.runs_scored = a_c.runs_scored.str.replace("*","")

# %%
a_c.runs_scored = a_c.runs_scored.astype("int64")

# %%
a_c.runs_scored.sum()
# Out:
# 1814

# %%
sns.barplot(x = "year",y="runs_scored",data = a_c)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
a_c.runs_scored.mean()
# Out:
# 27.907692307692308

# %% [markdown]
# ## Catches Taken

# %%
a_c.catches = a_c.catches.astype("int64")

# %%
a_c.catches.sum()
# Out:
# 71

# %% [markdown]
# ## Stumpings

# %%
a_c.stumpings = a_c.stumpings.astype("int64")

# %%
a_c.stumpings.sum()
# Out:
# 7

# %% [markdown]
# ## Best Performance

# %%
a_c.groupby(["runs_scored"]).max()
# Out:
#              player_id player_name wickets runs_conceded  catches  stumpings  \
# runs_scored
# 0                    3  Alex Carey       -             -        1          0
# 1                    3  Alex Carey       -             -        2          0
# 2                    3  Alex Carey       -             -        0          0
# 3                    3  Alex Carey       -             -        4          2
# 4                    3  Alex Carey       -             -        4          0
# 5                    3  Alex Carey       -             -        2          0
# 6                    3  Alex Carey       -             -        0          0
# 10                   3  Alex Carey       -             -        1          0
# 11                   3  Alex Carey       -             -        1          0
# 12                   3  Alex Carey       -             -        2          0
# 14                   3  Alex Carey       -             -        3          0
# ...

# %% [markdown]
# ## 19. Ravindra Jadeja

# %%
r_j = data[(data["player_name"] == "Ravindra Jadeja") & (data["runs_scored"]!= "TDNB") & (data["runs_scored"]!="DNB") & (data["runs_conceded"]!="-")]

# %% [markdown]
# ## Total Runs Scored

# %%
r_j.runs_scored = r_j.runs_scored.str.replace("*","")

# %%
r_j.runs_scored = r_j.runs_scored.astype("int64")

# %%
r_j.runs_scored.sum()
# Out:
# 2588

# %%
sns.barplot(x= "year",y= "runs_scored",data = r_j)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
r_j.runs_scored.mean()
# Out:
# 21.040650406504064

# %% [markdown]
# ## Total Wickets Taken

# %%
r_j.wickets = r_j.wickets.astype("int64")

# %%
r_j.wickets.sum()
# Out:
# 127

# %% [markdown]
# ## Average Wickets Taken

# %%
r_j.wickets.mean()
# Out:
# 1.032520325203252

# %% [markdown]
# ## Total Runs Conceded

# %%
r_j.runs_conceded = r_j.runs_conceded.astype("int64")

# %%
r_j.runs_conceded.sum()
# Out:
# 5375

# %% [markdown]
# ## Average Runs Conceded

# %%
r_j.runs_conceded.mean()
# Out:
# 43.699186991869915

# %% [markdown]
# ## Wickets VS Runs Conceded

# %%
sns.barplot(x = "wickets",y = "runs_conceded",data=r_j)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# ## Best Performance

# %%
r_j.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id      player_name  runs_conceded catches  \
# runs_scored wickets
# 0           0               22  Ravindra Jadeja             52       1
#             1               22  Ravindra Jadeja             61       2
#             2               22  Ravindra Jadeja             74       1
#             3               22  Ravindra Jadeja             73       1
# 1           1               22  Ravindra Jadeja             64       0
# ...                        ...              ...            ...     ...
# 66          1               22  Ravindra Jadeja             62       1
#             2               22  Ravindra Jadeja             47       1
# 77          1               22  Ravindra Jadeja             34       2
# 78          2               22  Ravindra Jadeja             42       0
# 87          0               22  Ravindra Jadeja             66       0
#
#                     stumpings match_date                   opposition  \
# runs_scored wickets
# ...

# %% [markdown]
# ## 20. KL Rahul

# %%
k_r = data[(data["player_name"]=="KL Rahul") & (data["runs_scored"]!= "TDNB")&(data["runs_scored"]!= "DNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
k_r.runs_scored = k_r.runs_scored.str.replace("*","")

# %%
k_r.runs_scored = k_r.runs_scored.astype("int64")

# %%
k_r.runs_scored.sum()
# Out:
# 2291

# %%
sns.barplot(x = "year",y= "runs_scored",data=k_r)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
k_r.runs_scored.mean()
# Out:
# 39.5

# %% [markdown]
# ## Catches

# %%
k_r.catches = k_r.catches.astype("int64")

# %%
k_r.catches.sum()
# Out:
# 36

# %% [markdown]
# ## Stumpings

# %%
k_r.stumpings = k_r.stumpings.astype("int64")

# %%
k_r.stumpings.sum()
# Out:
# 4

# %% [markdown]
# ## Best Performance

# %%
k_r.groupby(["runs_scored"]).max()
# Out:
#              player_id player_name wickets runs_conceded  catches  stumpings  \
# runs_scored
# 0                   21    KL Rahul       -             -        0          0
# 1                   21    KL Rahul       -             -        0          0
# 4                   21    KL Rahul       -             -        0          0
# 5                   21    KL Rahul       -             -        2          0
# 6                   21    KL Rahul       -             -        0          0
# 7                   21    KL Rahul       -             -        1          0
# 8                   21    KL Rahul       -             -        0          0
# 9                   21    KL Rahul       -             -        1          0
# 11                  21    KL Rahul       -             -        1          0
# 12                  21    KL Rahul       -             -        3          0
# 14                  21    KL Rahul       -             -        1          0
# ...

# %% [markdown]
# ## 21. Marnus Labuschagne

# %%
ml = data[(data["player_name"]=='Marnus Labuschagne') & (data["runs_scored"]!="TDNB")& (data["runs_scored"]!="DNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
ml.runs_scored = ml.runs_scored.str.replace("*","")

# %%
ml.runs_scored = ml.runs_scored.astype("int64")

# %%
ml.runs_scored.sum()
# Out:
# 1268

# %%
sns.barplot(x= "year",y = "runs_scored",data = ml)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
ml.runs_scored.mean()
# Out:
# 35.22222222222222

# %% [markdown]
# ## Best Performance

# %%
ml.groupby(["runs_scored"]).max()
# Out:
#              player_id         player_name wickets runs_conceded catches  \
# runs_scored
# 0                    6  Marnus Labuschagne       0            11       0
# 2                    6  Marnus Labuschagne       -             -       0
# 4                    6  Marnus Labuschagne       0            31       1
# 5                    6  Marnus Labuschagne       -             -       0
# 7                    6  Marnus Labuschagne       -             -       1
# 8                    6  Marnus Labuschagne       -             -       1
# 14                   6  Marnus Labuschagne       0            13       0
# 15                   6  Marnus Labuschagne       -             -       1
# 18                   6  Marnus Labuschagne       0            13       0
# 20                   6  Marnus Labuschagne       -             -       0
# 21                   6  Marnus Labuschagne       -             -       2
# 24                   6  Marnus Labuschagne       2            19       0
# ...

# %% [markdown]
# ## 22.Shreyas Iyer

# %%
si = data[(data["player_name"]=="Shreyas Iyer") & (data["runs_scored"]!="DNB")&(data["runs_scored"]!="TDNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
si.runs_scored = si.runs_scored.str.replace("*","")
si.runs_scored = si.runs_scored.astype("int64")

# %%
si.runs_scored.sum()
# Out:
# 1801

# %%
sns.barplot(x = 'year',y= 'runs_scored',data=si)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
si.runs_scored.mean()
# Out:
# 42.88095238095238

# %% [markdown]
# ## Best Performance

# %%
si.groupby(["runs_scored"]).max()
# Out:
#              player_id   player_name wickets runs_conceded catches stumpings  \
# runs_scored
# 2                   20  Shreyas Iyer       -             -       0         0
# 3                   20  Shreyas Iyer       -             -       1         0
# 4                   20  Shreyas Iyer       -             -       0         0
# 6                   20  Shreyas Iyer       -             -       0         0
# 7                   20  Shreyas Iyer       -             -       0         0
# 9                   20  Shreyas Iyer       -             -       0         0
# 11                  20  Shreyas Iyer       0             1       0         0
# 14                  20  Shreyas Iyer       -             -       -         -
# 17                  20  Shreyas Iyer       -             -       0         0
# 18                  20  Shreyas Iyer       -             -       0         0
# 19                  20  Shreyas Iyer       -             -       0         0
# ...

# %% [markdown]
# ## 23. Shubman Gill

# %%
sg = data[(data["player_name"]=="Shubman Gill")& (data["runs_scored"]!="TDNB")&(data["runs_scored"]!="DNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
sg.runs_scored = sg.runs_scored.str.replace("*","")
sg.runs_scored = sg.runs_scored.astype("int64")

# %%
sg.runs_scored.sum()
# Out:
# 1917

# %%
sns.barplot(x = "year",y="runs_scored",data=sg)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
sg.runs_scored.mean()
# Out:
# 54.77142857142857

# %% [markdown]
# ## Best Performance

# %%
sg.groupby(["runs_scored"]).max()
# Out:
#              player_id   player_name wickets runs_conceded catches stumpings  \
# runs_scored
# 0                   18  Shubman Gill       -             -       0         0
# 3                   18  Shubman Gill       -             -       0         0
# 7                   18  Shubman Gill       -             -       1         0
# 9                   18  Shubman Gill       -             -       0         0
# 10                  18  Shubman Gill       -             -       -         -
# 13                  18  Shubman Gill       -             -       0         0
# 19                  18  Shubman Gill       -             -       2         0
# 20                  18  Shubman Gill       -             -       2         0
# 21                  18  Shubman Gill       -             -       0         0
# 27                  18  Shubman Gill       -             -       0         0
# 28                  18  Shubman Gill       -             -       0         0
# ...

# %% [markdown]
# ## 24.Shardul Thakur

# %%
st = data[(data["player_name"]=="Shardul Thakur") & (data["runs_scored"]!="TDNB") & (data["runs_scored"]!="DNB") & (data["runs_conceded"]!="-")]

# %% [markdown]
# ## Total Runs Scored

# %%
st.runs_scored = st.runs_scored.str.replace("*","")
st.runs_scored = st.runs_scored.astype("int64")

# %%
st.runs_scored.sum()
# Out:
# 326

# %%
sns.barplot(x = 'year',y='runs_scored',data=st)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
st.runs_scored.mean()
# Out:
# 13.583333333333334

# %% [markdown]
# ## Total Wickets Taken

# %%
st.wickets = st.wickets.astype('int64')

# %%
st.wickets.sum()
# Out:
# 37

# %% [markdown]
# ## Average Wickets Taken

# %%
st.wickets.mean()
# Out:
# 1.5416666666666667

# %% [markdown]
# ## Total Runs Conceded

# %%
st.runs_conceded = st.runs_conceded.astype("int64")

# %%
st.runs_conceded.sum()
# Out:
# 1196

# %% [markdown]
# ## Average Runs Conceded

# %%
st.runs_conceded.mean()
# Out:
# 49.833333333333336

# %% [markdown]
# ## Wickets Vs Runs Conceded

# %%
sns.barplot(x="wickets",y="runs_conceded",data=st)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# ## Best Performance

# %%
st.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id     player_name  runs_conceded catches  \
# runs_scored wickets
# 0           0               23  Shardul Thakur             54       0
# 1           1               23  Shardul Thakur             63       0
# 2           1               23  Shardul Thakur             21       0
# 3           2               23  Shardul Thakur             54       0
#             3               23  Shardul Thakur             54       1
# 7           0               23  Shardul Thakur             47       0
#             1               23  Shardul Thakur             87       0
#             2               23  Shardul Thakur             54       1
# 8           2               23  Shardul Thakur             41       0
# 9           1               23  Shardul Thakur             55       0
# 11          3               23  Shardul Thakur             65       0
# 13          0               23  Shardul Thakur             43       0
# ...

# %% [markdown]
# ## 26. Surya Kumar Yadav

# %%
sky = data[(data["player_name"]=="Suryakumar Yadav")&(data["runs_scored"]!="DNB")&(data["runs_scored"]!="TDNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
sky.runs_scored = sky.runs_scored.str.replace("*","")
sky.runs_scored = sky.runs_scored.astype("int64")

# %%
sky.runs_scored.sum()
# Out:
# 667

# %%
sns.barplot(x= "year",y = "runs_scored",data = sky)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
sky.runs_scored.mean()
# Out:
# 23.821428571428573

# %% [markdown]
# ## Best Performance

# %%
sky.groupby(["runs_scored"]).max()
# Out:
#              player_id       player_name wickets runs_conceded catches  \
# runs_scored
# 0                   30  Suryakumar Yadav       -             -       0
# 4                   30  Suryakumar Yadav       -             -       1
# 6                   30  Suryakumar Yadav       -             -       1
# 8                   30  Suryakumar Yadav       -             -       0
# 9                   30  Suryakumar Yadav       -             -       0
# 13                  30  Suryakumar Yadav       -             -       0
# 14                  30  Suryakumar Yadav       -             -       0
# 16                  30  Suryakumar Yadav       -             -       1
# 19                  30  Suryakumar Yadav       -             -       0
# 24                  30  Suryakumar Yadav       -             -       0
# 26                  30  Suryakumar Yadav       -             -       0
# 27                  30  Suryakumar Yadav       -             -       1
# ...

# %% [markdown]
# ## 27. Mohammed Siraj

# %%
mos = data[(data["player_name"]=="Mohammed Siraj") & (data["runs_conceded"]!="-")]

# %%
mos
# Out:
#       player_id     player_name runs_scored wickets runs_conceded catches  \
# 648          25  Mohammed Siraj           1       1            68       0
# 1034         25  Mohammed Siraj         DNB       3            29       1
# 1055         25  Mohammed Siraj           0       0            37       0
# 1075         25  Mohammed Siraj          3*       2            37       0
# 1117         25  Mohammed Siraj         DNB       0            76       0
# 2086         25  Mohammed Siraj         DNB       1            26       0
# 2093         25  Mohammed Siraj           3       1            38       0
# 2098         25  Mohammed Siraj           4       3            29       0
# 2119         25  Mohammed Siraj         DNB       2            66       0
# 2127         25  Mohammed Siraj           9       3            32       1
# 2133         25  Mohammed Siraj           2       2            73       0
# 2140         25  Mohammed Siraj          7*       2            30       0
# ...

# %% [markdown]
# ## Total Wickets Taken

# %%
mos.wickets = mos.wickets.astype("int64")

# %%
mos.wickets.sum()
# Out:
# 54

# %% [markdown]
# ## Average Wickets Taken

# %%
mos.wickets.mean()
# Out:
# 1.8620689655172413

# %% [markdown]
# ## Total Runs Conceded

# %%
mos.runs_conceded = mos.runs_conceded.astype("int64")

# %%
mos.runs_conceded.sum()
# Out:
# 1081

# %% [markdown]
# ## Average Runs Conceded

# %%
mos.runs_conceded.mean()
# Out:
# 37.275862068965516

# %% [markdown]
# ## Wickets vs Runs Conceded

# %%
sns.barplot(x="wickets",y="runs_conceded",data=mos)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# ## Best Performance

# %%
mos.groupby(["wickets"]).max()
# Out:
#          player_id     player_name runs_scored  runs_conceded catches  \
# wickets
# 0               25  Mohammed Siraj         DNB             76       0
# 1               25  Mohammed Siraj         DNB             68       2
# 2               25  Mohammed Siraj         DNB             73       0
# 3               25  Mohammed Siraj         DNB             61       1
# 4               25  Mohammed Siraj         DNB             46       0
# 6               25  Mohammed Siraj         DNB             21       0
#
#         stumpings match_date                      opposition  match_id  year
# wickets
# 0               0 2023-09-10     v West Indies Port of Spain       478  2023
# 1               0 2023-09-27               v Zimbabwe Harare       548  2023
# 2               0 2023-03-22     v West Indies Port of Spain       480  2023
# 3               0 2023-09-04         v West Indies Ahmedabad       479  2023
# ...

# %% [markdown]
# ## 28. Ishan Kishan

# %%
ik = data[(data["player_name"]=="Ishan Kishan") & (data["runs_scored"]!="TDNB") & (data["runs_scored"]!="DNB")]

# %% [markdown]
# ## Total Runs Scored

# %%
ik.runs_scored = ik.runs_scored.str.replace("*","")
ik.runs_scored = ik.runs_scored.astype("int64")

# %%
ik.runs_scored.sum()
# Out:
# 886

# %%
sns.barplot(x = "year",y="runs_scored",data=ik)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
ik.runs_scored.mean()
# Out:
# 40.27272727272727

# %% [markdown]
# ## Best Performance

# %%
ik.groupby(["runs_scored"]).max()
# Out:
#              player_id   player_name wickets runs_conceded catches stumpings  \
# runs_scored
# 1                   29  Ishan Kishan       -             -       1         0
# 3                   29  Ishan Kishan       -             -       0         0
# 5                   29  Ishan Kishan       -             -       0         0
# 6                   29  Ishan Kishan       -             -       1         0
# 8                   29  Ishan Kishan       -             -       1         0
# 10                  29  Ishan Kishan       -             -       0         0
# 17                  29  Ishan Kishan       -             -       1         1
# 18                  29  Ishan Kishan       -             -       0         0
# 20                  29  Ishan Kishan       -             -       0         0
# 23                  29  Ishan Kishan       -             -       2         0
# 28                  29  Ishan Kishan       -             -       0         0
# ...

# %% [markdown]
# ## 29.Cameron Green

# %%
cg = data[(data["player_name"]=="Cameron Green")& (data["runs_scored"]!="DNB")& (data["runs_scored"]!="TDNB")& (data["runs_conceded"]!="-")]

# %% [markdown]
# ## Total Runs Scored

# %%
cg.runs_scored = cg.runs_scored.str.replace("*","")
cg.runs_scored = cg.runs_scored.astype("int64")

# %%
cg.runs_scored.sum()
# Out:
# 379

# %%
sns.barplot(x= "year",y="runs_scored",data=cg)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
cg.runs_scored.mean()
# Out:
# 22.294117647058822

# %% [markdown]
# ## Total Wickets Taken

# %%
cg.wickets = cg.wickets.astype("int64")

# %%
cg.wickets.sum()
# Out:
# 9

# %% [markdown]
# ## Average Wickets Taken

# %%
cg.wickets.mean()
# Out:
# 0.5294117647058824

# %% [markdown]
# ## Total Runs Conceded

# %%
cg.runs_conceded = cg.runs_conceded.astype("int64")

# %%
cg.runs_conceded.sum()
# Out:
# 585

# %% [markdown]
# ## Average Runs Conceded

# %%
cg.runs_conceded.mean()
# Out:
# 34.411764705882355

# %% [markdown]
# ## Wickets vs Runs Conceded

# %%
sns.barplot(x = "wickets",y = "runs_conceded",data = cg)
# Out:
# <Axes: xlabel='wickets', ylabel='runs_conceded'>

# %% [markdown]
# ## Best Performance

# %%
cg.groupby(["runs_scored","wickets"]).max()
# Out:
#                      player_id    player_name  runs_conceded catches  \
# runs_scored wickets
# 0           1                7  Cameron Green             32       1
# 3           1                7  Cameron Green             17       1
# 5           0                7  Cameron Green             35       0
# 9           1                7  Cameron Green             30       0
# 12          0                7  Cameron Green             35       1
# 13          0                7  Cameron Green             27       0
# 15          0                7  Cameron Green             30       0
# 18          1                7  Cameron Green             59       1
# 19          2                7  Cameron Green            103       0
# 20          0                7  Cameron Green             38       0
# 21          0                7  Cameron Green             27       0
# 25          1                7  Cameron Green             13       1
# ...

# %% [markdown]
# ## 30.Josh Inglis

# %%
ji = data[(data["player_name"]=="Josh Inglis") & (data["runs_scored"]!="TDNB") & (data["runs_scored"]!="DNB") ]

# %% [markdown]
# ## Total Runs Scored

# %%
ji.runs_scored = ji.runs_scored.str.replace("*","")
ji.runs_scored = ji.runs_scored.astype("int64")

# %%
ji.runs_scored.sum()
# Out:
# 143

# %%
sns.barplot(x= "year",y="runs_scored",data= ji)
# Out:
# <Axes: xlabel='year', ylabel='runs_scored'>

# %% [markdown]
# ## Average Runs Scored

# %%
ji.runs_scored.mean()
# Out:
# 17.875

# %% [markdown]
# ## Catches

# %%
ji.catches = ji.catches.astype("int64")

# %%
ji.catches.sum()
# Out:
# 2

# %% [markdown]
# ## Stumpings

# %%
ji.stumpings = ji.stumpings.astype("int64")

# %%
ji.stumpings.sum()
# Out:
# 0

# %% [markdown]
# ## Best Performance

# %%
ji.groupby(["runs_scored"]).max()
# Out:
#              player_id  player_name wickets runs_conceded  catches  stumpings  \
# runs_scored
# 0                    4  Josh Inglis       -             -        1          0
# 1                    4  Josh Inglis       -             -        0          0
# 5                    4  Josh Inglis       -             -        0          0
# 6                    4  Josh Inglis       -             -        0          0
# 10                   4  Josh Inglis       -             -        0          0
# 26                   4  Josh Inglis       -             -        0          0
# 45                   4  Josh Inglis       -             -        1          0
# 50                   4  Josh Inglis       -             -        0          0
#
#             match_date                   opposition  match_id  year
# runs_scored
# 0           2023-09-17  v South Africa Johannesburg       183  2023
# 1           2023-09-07  v South Africa Bloemfontein       179  2023
# ...

# %% [markdown]
# ## TOP 5 BATSMAN

# %%
bat =  data[(data["runs_scored"]!="DNB")& (data["runs_scored"]!="TDNB")]

# %%
bat.runs_scored = bat.runs_scored.str.replace("*","")
bat.runs_scored = bat.runs_scored.astype("int64")

# %%
batsmen_stats = bat.groupby('player_name')['runs_scored'].sum().reset_index()
top_5_batsmen = batsmen_stats.sort_values(by='runs_scored', ascending=False).head(5)
print("Top 5 Batsmen:")
print(top_5_batsmen)
# Out:
# Top 5 Batsmen:
#       player_name  runs_scored
# 29    Virat Kohli        13083
# 21   Rohit Sharma        10112
# 3    David Warner         6397
# 26    Steve Smith         5054
# 4   Glenn Maxwell         3495

# %% [markdown]
# ## TOP 5 Bowler

# %%
bow = data[(data["runs_conceded"]!="-")]

# %%
bow.wickets = bow.wickets.astype('int64')

# %%
bowlers_stats = bow.groupby('player_name')['wickets'].sum().reset_index()
top_5_bowlers = bowlers_stats.sort_values(by='wickets', ascending=False).head(5)
print("\nTop 5 Bowlers:")
print(top_5_bowlers)
# Out:
# Top 5 Bowlers:
#             player_name  wickets
# 11      Mitchell Starc.      220
# 16      Ravindra Jadeja      204
# 12       Mohammed Shami      171
# 15  Ravichandran Ashwin      155
# 7         Kuldeep Yadav      152

# %% [markdown]
# ## THANKS FOR REVIEWING THIS ANALYSIS
