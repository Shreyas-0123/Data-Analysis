# %%
# importing required libraries
import pandas as pd
from pandas import DataFrame as df
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing data from dataset
data = pd.read_excel(r"C:\Users\SHREYAS\Downloads\Downloads\trending_football_players.xlsx")

# %%
data.head()
# Out:
#       Player_name                                            Images  Age  \
# 0       T. Almada  https://cdn.sofifa.net/players/245/371/24_60.png   22
# 1        L. Palma               https://cdn.sofifa.net/player_0.svg   23
# 2        R. Lavia  https://cdn.sofifa.net/players/263/620/24_60.png   19
# 3  W. Zaïre-Emery  https://cdn.sofifa.net/players/270/673/24_60.png   17
# 4     Gabri Veiga  https://cdn.sofifa.net/players/258/729/24_60.png   21
#
#   National_team            Positions  Overall  Potential_overall  \
# 0     Argentina  ['CAM', 'CM', 'CF']       79                 87
# 1      Honduras               ['LW']       69                 75
# 2       Belgium              ['CDM']       73                 86
# 3        France        ['CM', 'CDM']       77                 89
# 4         Spain        ['CM', 'CAM']       78                 89
#
#           Current_club Current_contract   Value  Wage  Total_stats
# 0       Atlanta United      2022 ~ 2025  €39.5M  €10K         2050
# ...

# %%
# Basic info 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player_name        3000 non-null   object
#  1   Images             3000 non-null   object
#  2   Age                3000 non-null   int64
#  3   National_team      3000 non-null   object
#  4   Positions          3000 non-null   object
#  5   Overall            3000 non-null   int64
#  6   Potential_overall  3000 non-null   int64
#  7   Current_club       3000 non-null   object
#  8   Current_contract   3000 non-null   object
#  9   Value              3000 non-null   object
#  10  Wage               3000 non-null   object
#  11  Total_stats        3000 non-null   int64
# dtypes: int64(4), object(8)
# memory usage: 281.4+ KB

# %%
#Analysis

# %% [markdown]
# ## Top 10 Players By Overall

# %%
top_10 = data.sort_values(by='Overall', ascending=False).head(11)

# %%
top_10
# Out:
#         Player_name                                            Images  Age  \
# 200    K. De Bruyne  https://cdn.sofifa.net/players/192/985/24_60.png   32
# 41       E. Haaland  https://cdn.sofifa.net/players/239/085/24_60.png   22
# 43        K. Mbappé  https://cdn.sofifa.net/players/231/747/24_60.png   24
# 543      K. Benzema  https://cdn.sofifa.net/players/165/153/24_60.png   35
# 70         L. Messi  https://cdn.sofifa.net/players/158/023/24_60.png   36
# 181  R. Lewandowski  https://cdn.sofifa.net/players/188/545/24_60.png   34
# 360      K. Benzema  https://cdn.sofifa.net/players/165/153/24_60.png   35
# 62          H. Kane  https://cdn.sofifa.net/players/202/126/24_60.png   29
# 128       Neymar Jr  https://cdn.sofifa.net/players/190/871/24_60.png   31
# 979     V. van Dijk  https://cdn.sofifa.net/players/203/376/24_60.png   31
# 121        Vini Jr.  https://cdn.sofifa.net/players/238/794/24_60.png   22
#
#     National_team      Positions  Overall  Potential_overall  \
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = "Player_name",y = "Overall",data = top_10)
plt.title("Top 10 Players By Overall",size = 20,weight = "bold")
# Out:
# Text(0.5, 1.0, 'Top 10 Players By Overall')

# %% [markdown]
# ## Top 10 Players By Potential Overall

# %%
data.sort_values(by = "Potential_overall",ascending = False).head(10)
# Out:
#            Player_name                                            Images  Age  \
# 43           K. Mbappé  https://cdn.sofifa.net/players/231/747/24_60.png   24
# 121           Vini Jr.  https://cdn.sofifa.net/players/238/794/24_60.png   22
# 41          E. Haaland  https://cdn.sofifa.net/players/239/085/24_60.png   22
# 21          J. Musiala  https://cdn.sofifa.net/players/256/790/24_60.png   20
# 11    K. Kvaratskhelia  https://cdn.sofifa.net/players/247/635/24_60.png   22
# 44         F. Valverde  https://cdn.sofifa.net/players/239/053/24_60.png   24
# 139              Pedri  https://cdn.sofifa.net/players/251/854/24_60.png   20
# 200       K. De Bruyne  https://cdn.sofifa.net/players/192/985/24_60.png   32
# 18            F. Wirtz  https://cdn.sofifa.net/players/256/630/24_60.png   20
# 2284      11\n Ronaldo  https://cdn.sofifa.net/players/037/576/11_60.png   33
#
#      National_team            Positions  Overall  Potential_overall  \
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = "Player_name",y = "Potential_overall",data = top_10)
plt.title("Top 10 Players By Potential Overall",size = 20,weight = "bold")
# Out:
# Text(0.5, 1.0, 'Top 10 Players By Potential Overall')

# %% [markdown]
# ## Top 10 Players By Total Stats

# %%
top_s_10 = data.sort_values(by = "Total_stats",ascending = False).head(11)
top_s_10
# Out:
#          Player_name                                            Images  Age  \
# 370  Bruno Fernandes  https://cdn.sofifa.net/players/212/198/24_60.png   28
# 94      A. Griezmann  https://cdn.sofifa.net/players/194/765/24_60.png   32
# 242       J. Kimmich  https://cdn.sofifa.net/players/212/622/24_60.png   28
# 303       J. Kimmich  https://cdn.sofifa.net/players/212/622/24_60.png   28
# 200     K. De Bruyne  https://cdn.sofifa.net/players/192/985/24_60.png   32
# 373         M. Acuña  https://cdn.sofifa.net/players/224/334/24_60.png   31
# 432         M. Acuña  https://cdn.sofifa.net/players/224/334/24_60.png   31
# 369      L. Goretzka  https://cdn.sofifa.net/players/209/658/24_60.png   28
# 32        N. Barella  https://cdn.sofifa.net/players/224/232/24_60.png   26
# 44       F. Valverde  https://cdn.sofifa.net/players/239/053/24_60.png   24
# 652        S. Tonali  https://cdn.sofifa.net/players/241/096/24_60.png   23
#
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = "Player_name",y = "Total_stats",data = top_s_10)
plt.title("Top 10 Players By Total Stats",size = 20,weight = "bold")
# Out:
# Text(0.5, 1.0, 'Top 10 Players By Total Stats')

# %% [markdown]
# ## Most Valuable Player

# %%
# Function to Convert Denomination into suitable form to Do Analysis
def convert_value_to_numeric(value_str):
    if value_str.endswith('M'):
        return float(value_str.replace('€', '').replace('M', '')) * 1000000
    elif value_str.endswith('K'):
        return float(value_str.replace('€', '').replace('K', '')) * 1000

    else:
        return float(value_str.replace('€', ''))

# %%
data['Value (Numeric)'] = data['Value'].apply(convert_value_to_numeric)
most_valuable_player = data.loc[data['Value (Numeric)'].idxmax()]
print(most_valuable_player[['Player_name', 'Value']])
# Out:
# Player_name    E. Haaland
# Value               €185M
# Name: 41, dtype: object

# %% [markdown]
# ## Player with Highest Wage

# %%
# Function to Convert Denomination into suitable form to Do Analysis
def convert_wage_to_numeric(wage_str):
    value_str = wage_str.replace('€', '').replace('K', '').replace('M', '')
    unit = wage_str[-1]
    if unit == 'M':
        return float(value_str) * 1000000
    elif unit == 'K':
        return float(value_str) * 10000
    else:
        return float(value_str)
data['Wage (Numeric)'] = data['Wage'].apply(convert_wage_to_numeric)
player_with_highest_wage = data.loc[data['Wage (Numeric)'].idxmax()]
print(player_with_highest_wage[['Player_name', 'Wage']])
# Out:
# Player_name    K. De Bruyne
# Wage                  €350K
# Name: 200, dtype: object

# %% [markdown]
# ## National Teams Ranking On the Basis of Performance

# %%
avg_overall = data.groupby('National_team')['Overall'].mean().reset_index()
sorted_teams = avg_overall.sort_values(by='Overall', ascending=False)
print(sorted_teams)
# Out:
#                 National_team  Overall
# 16   Central African Republic     81.0
# 67                      Malta     79.0
# 51                       Iran     79.0
# 100                      Togo     78.0
# 70                 Montenegro     77.5
# ..                        ...      ...
# 96                      Sudan     62.0
# 64                  Lithuania     61.0
# 94               South Africa     59.0
# 41                  Gibraltar     58.0
# 58                      Kenya     52.0
#
# [112 rows x 2 columns]

# %% [markdown]
# ## Clubs Ranking on the Basis of Performance

# %%
club_avg_ratings = data.groupby('Current_club')['Overall'].mean().sort_values(ascending=False)
print(club_avg_ratings)
# Out:
# Current_club
# Al Ittihad              85.666667
# Al Shabab               84.000000
# Spain                   83.000000
# FC Barcelona            81.807692
# Al Nassr                81.375000
#                           ...
# Notts County            53.000000
# Varberg BoIS            53.000000
# Dynamo Dresden          53.000000
# UCD                     52.000000
# Sporting Kansas City    49.000000
# Name: Overall, Length: 475, dtype: float64
